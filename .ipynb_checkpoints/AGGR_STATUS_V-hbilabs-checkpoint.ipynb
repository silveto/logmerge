# %%
import pandas as pd
import numpy as np
import re # Regular expression library

# StringIO - to read dataframe from string
import sys
if sys.version_info[0] < 3: 
    from StringIO import StringIO
else:
    from io import StringIO

# %%
file_name = "../data/AGGR-STATUS-V/AGGR-STATUS-V_NASKNX07A.txt"
with open(file_name, 'r') as open_file:
    txt = open_file.read()
    separate_logs = txt.split('\n\n#') # Note: Different split string as blank line (\n\n) is not enough here

# %%
table_data = []
for log in separate_logs:
    if not "ERROR" in log and log != '':
        log = log.strip()
        
        # Get log info
        log_info = re.match( r'(.* \d{4}).*\((.*)\) INFO\n# hostname: (.*) serialno: (\d+)\n.*', log, re.M).groups()  
        _date = log_info[0]
        _type = log_info[1]
        _hostname = log_info[2]
        _serial_no = log_info[3]
        
        print(_date,_type,_hostname,_serial_no)
        
        # Get aggr name and volumes names
        log_agg_volumes = re.findall(r'\s(aggr[A-Za-z0-9_]*)\sonline.*?\sVolumes: (.*?)\n\n+?', log, re.M|re.DOTALL)
        for agg_volumes in log_agg_volumes:
            _agg_name = agg_volumes[0]           
            volumes = [v.strip() for v in agg_volumes[1].split(',')]
            for _vol in volumes:
                table_data.append(
                    (
                    _date,
                    _type,
                    _hostname,
                    _serial_no,
                    _agg_name,
                    _vol
                    )
                )

df = pd.DataFrame(table_data, columns=['date', 'ASUP_Type','hostname','serial_no','agg','vol'])
df['date'] = pd.to_datetime(df['date'], format='%a %b %d %H:%M:%S %Y')
# Out:
# Sun Jul  2 00:34:30 2017 WEEKLY_LOG NASKNX07A 451416000026
# Sun Jun 25 00:33:39 2017 WEEKLY_LOG NASKNX07A 451416000026
# Sun Jun 18 00:22:49 2017 WEEKLY_LOG NASKNX07A 451416000026
# Sun Jun 11 00:22:06 2017 WEEKLY_LOG NASKNX07A 451416000026

# %%
df
# Out:
#                    date   ASUP_Type   hostname     serial_no          agg  \
# 0   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026        aggr0
# 1   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 2   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 3   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 4   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 5   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 6   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 7   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 8   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 9   2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 10  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 11  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 12  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 13  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 14  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 15  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 16  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 17  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 18  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 19  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 20  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 21  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 22  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 23  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 24  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 25  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 26  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 27  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 28  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 29  2017-07-02 00:34:30  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# ..                  ...         ...        ...           ...          ...
# 285 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 286 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 287 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 288 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 289 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 290 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 291 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 292 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 293 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 294 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 295 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 296 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 297 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 298 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 299 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 300 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 301 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 302 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 303 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 304 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 305 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 306 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 307 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 308 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 309 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 310 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 311 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 312 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 313 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
# 314 2017-06-11 00:22:06  WEEKLY_LOG  NASKNX07A  451416000026  aggr01_nsas
#
#                           vol
# 0                        vol0
# 1     vf_NAS_AURDIVIC_rootvol
# 2      wd_aurdivic_hobo_vol01
# 3    wd_aurdivic_branch_vol01
# 4      vf_NAS_AURDI02_rootvol
# 5            A3DOCKD0052_USER
# 6         A3DOCKD0052_PROFILE
# 7          A3DOCKD0052_SHARED
# 8       vf_NAS_AURINT_rootvol
# 9      vf_NAS_AURIACT_rootvol
# 10     vf_NAS_AURITAS_rootvol
# 11    wd_auriact_branch_vol01
# 12    wd_auritas_branch_vol01
# 13     wd_aurint_branch_vol01
# 14     vf_NAS_AURIQLD_rootvol
# 15      wd_auriqld_hobo_vol01
# 16    wd_auriqld_branch_vol01
# 17    wd_auriqld_branch_vol02
# 18    wd_auriqld_branch_vol03
# 19    wd_auriqld_branch_vol04
# 20    wd_auriqld_branch_vol05
# 21    wd_auriqld_branch_vol06
# 22    wd_auriqld_branch_vol07
# 23    wd_auriqld_branch_vol08
# 24    wd_auriqld_branch_vol09
# 25      vf_NAS_AURIWA_rootvol
# 26     wd_auriwa_branch_vol01
# 27     wd_auriwa_branch_vol02
# 28     wd_auriwa_branch_vol03
# 29     wd_auriwa_branch_vol04
# ..                        ...
# 285    vf_NAS_WA_HOBO_rootvol
# 286    vf_NAS_SA_HOBO_rootvol
# 287   wd_aurinsw_branch_vol01
# 288   wd_aurinsw_branch_vol02
# 289   wd_aurinsw_branch_vol03
# 290   wd_aurinsw_branch_vol04
# 291   wd_aurinsw_branch_vol05
# 292   wd_aurinsw_branch_vol06
# 293   wd_aurinsw_branch_vol07
# 294   wd_aurinsw_branch_vol08
# 295   wd_aurinsw_branch_vol09
# 296   wd_aurinsw_branch_vol10
# 297   wd_aurinsw_branch_vol11
# 298   wd_aurinsw_branch_vol12
# 299   wd_aurinsw_branch_vol13
# 300   wd_aurinsw_branch_vol14
# 301    vf_NAS_AURINSW_rootvol
# 302               sv_test_vol
# 303    wd_auriwa_branch_vol06
# 304            vol_SIF_Dev_01
# 305          prd_itf_mp_vol01
# 306                 vol_trace
# 307            vol_trace_test
# 308        vol_trace_test_qld
# 309      Siebel_App_Datavol01
# 310      Siebel_App_Datavol02
# 311      Siebel_App_Datavol03
# 312      Siebel_App_Datavol04
# 313           vf_test_rootvol
# 314                   TestVol
#
# [315 rows x 6 columns]

# %%
df.to_csv("data/df-agg-status.csv", index=False)
